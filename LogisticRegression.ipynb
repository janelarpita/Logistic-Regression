# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\janelarp\new folder\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\janelarp\new folder\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\janelarp\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv(r"C:\Users\janelarp\Downloads\LogisticRdataset.csv")

# %%
df
# Out:
#      Hours_Studied  Result
# 0             3.75       0
# 1             9.51       1
# 2             7.32       1
# 3             5.99       0
# 4             1.56       0
# ..             ...     ...
# 495           3.53       0
# 496           5.84       0
# 497           0.78       0
# 498           9.74       1
# 499           9.86       1
#
# [500 rows x 2 columns]

# %%
X = df[['Hours_Studied']] 
y = df['Result']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.92

# %%
y=np.array(y_test)
x=np.array(X_test)

plt.scatter(x,y)
plt.show()

# %%
X_curve = np.linspace(min(hours), max(hours), 300).reshape(-1, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 X_curve = np.linspace(min(hours), max(hours), 300).reshape(-1, 1)
#
# NameError: name 'hours' is not defined
